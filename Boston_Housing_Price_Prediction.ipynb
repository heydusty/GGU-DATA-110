# %% [markdown]
# # The Boston Housing Price Prediction
#
# Predicting median housing prices using **Linear Regression**, **Decision Tree**, and **Random Forest**.
#
# **Dataset columns:** CRIM, ZN, INDUS, CHAS, NX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV (target)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Load the Data

# %%
house = pd.read_csv('Boston.csv')
house.head(10)

# %%
house.tail()

# %% [markdown]
# ## Step 3: Data Exploration

# %%
house.shape

# %%
house.columns.tolist()

# %%
house.info()

# %%
house.isna().sum()

# %%
house.duplicated().sum()

# %%
house.describe().T

# %% [markdown]
# ## Step 4: Data Visualization

# %% [markdown]
# ### Distribution of Housing Prices (MEDV)

# %%
sns.histplot(house['MEDV'], bins=20, kde=True, color='green')
plt.title('Distribution of Housing Prices (MEDV)')
plt.xlabel('Median Housing Price ($1000s)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Boxplot — Distribution of Housing Age

# %%
sns.boxplot(y=house['AGE'], color='yellow')
plt.title('Distribution of Housing Age (AGE)')
plt.ylabel('Age (years)')
plt.show()

# %%
sns.boxplot(y=house['CRIM'], color='cyan')
plt.title('Distribution of Crime Rate (CRIM)')
plt.ylabel('Crime Rate')
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
sns.scatterplot(x='AGE', y='MEDV', data=house, color='green',
                edgecolor='black', alpha=0.7)
plt.title('Age of Building vs. Housing Prices')
plt.xlabel('Age of the Building')
plt.ylabel('Median Housing Price ($1000s)')
plt.show()

# %%
sns.scatterplot(x='RM', y='MEDV', data=house, color='lightblue',
                edgecolor='black', alpha=0.7)
plt.title('Rooms per Dwelling (RM) vs. Housing Prices (MEDV)')
plt.xlabel('Average Number of Rooms')
plt.ylabel('Median Housing Price ($1000s)')
plt.show()

# %%
sns.scatterplot(x='CRIM', y='MEDV', data=house, color='blue', alpha=0.7)
plt.title('Crime Rate vs. Housing Prices (MEDV)')
plt.xlabel('Crime Rate')
plt.ylabel('Median Housing Price ($1000s)')
plt.show()

# %% [markdown]
# ### Bar Plot — Average Housing Price by Highway Accessibility (RAD)

# %%
rad_medv_mean = house.groupby('RAD')['MEDV'].mean().reset_index()
sns.barplot(x='RAD', y='MEDV', data=rad_medv_mean, color='orange',
            edgecolor='black')
plt.title('Average House Price by Accessibility of Road Highways')
plt.xlabel('Accessibility of Road Highways (RAD)')
plt.ylabel('Mean Housing Price ($1000s)')
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(house.corr(numeric_only=True), annot=True,
            cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Boston Housing Features')
plt.show()

# %% [markdown]
# ## Step 5: Split the Data

# %%
from sklearn.model_selection import train_test_split

X = house.drop(columns=['MEDV'])
y = house['MEDV']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)
print('X_train:', X_train.shape)
print('X_test: ', X_test.shape)
print('y_train:', y_train.shape)
print('y_test: ', y_test.shape)

# %% [markdown]
# ## Step 6: Train the Models

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

error = mean_absolute_percentage_error(y_test, y_pred_lr)
print(f'Accuracy of Linear Regression: {(1 - error)*100:.2f}%')

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor(max_depth=5, random_state=42)
dtr.fit(X_train, y_train)
y_pred_dtr = dtr.predict(X_test)

error = mean_absolute_percentage_error(y_test, y_pred_dtr)
print(f'Accuracy of Decision Tree Regressor: {(1 - error)*100:.2f}%')

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train, y_train)
y_pred_rfr = rfr.predict(X_test)

error = mean_absolute_percentage_error(y_test, y_pred_rfr)
print(f'Accuracy of Random Forest Regressor: {(1 - error)*100:.2f}%')

# %% [markdown]
# ## Model Comparison
#
# | Model | Notes |
# |-------|-------|
# | Linear Regression | Simple baseline, ~78% |
# | Decision Tree | Better fit, ~88% |
# | **Random Forest** | **Best model, ~90%** — ensemble reduces overfitting |
#
# **Random Forest** is the best model due to its ensemble approach, which reduces overfitting and handles noise well.
